# %% [markdown]
# # <Jetson_Nano보드 내에서 Yolov5 이용 샘플 detection 코드 실행>
# * jetson nano set-up
# * Yolo v5 Tutorial in PC with Colab
# * choose target & prepare custom dataset(with labellmg)
# * traing custom dataset in PC with Colab
# * check real-time detection with Web-camera
# * prepare moving in Jetson nano(github clone set up)
# * do training in Jetson_Nano
# * confirm result
# * make a presentation(세팅과정, 학습결과, 성능지표 작성 포함)

# %% [markdown]
# ---
# ---
# # 메인: yolo v5 v6.0 yolov5n.pt 사용 custom dataset training & real-time detection

# %% [markdown]
# ---
# ## 1. git clone 및 필요 라이브러리 설치

# %%
#!git clone --branch v6.0 https://github.com/ultralytics/yolov5.git
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16517, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 16517 (delta 47), reused 50 (delta 16), pack-reused 16402
# Receiving objects: 100% (16517/16517), 15.12 MiB | 19.40 MiB/s, done.
# Resolving deltas: 100% (11309/11309), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 37.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 70.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 83.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ---
# ## 2. 현재 라이브러리 확인 및 커스텀데이터 업로드 - zip해제

# %%
import os
print('현재 작업 경로: ', os.getcwd())
# Out:
# 현재 작업 경로:  /content/yolov5

# %%
# !unzip ../custom_dataset.zip
# Out:
# Archive:  ../custom_dataset.zip
#   inflating: custom_dataset/data.yaml
#   inflating: custom_dataset/README.dataset.txt
#   inflating: custom_dataset/README.roboflow.txt
#    creating: custom_dataset/test/
#    creating: custom_dataset/test/images/
#   inflating: custom_dataset/test/images/0_Concern-In-China-As-Mystery-Virus-Spreads_jpg.rf.3135dfc5feab288d76a4ccfd22dfc5bf.jpg
#   inflating: custom_dataset/test/images/1224331650_g_400-w_g_jpg.rf.b816f49e2d84044fc997a8cbd55c347d.jpg
#   inflating: custom_dataset/test/images/126202-untitled-design-13_jpg.rf.56b50d413464989bb2232448a8fbb915.jpg
#   inflating: custom_dataset/test/images/1288126-10255706714jpg_jpg.rf.95f7324cbfd48e0386e0660b5e932223.jpg
#   inflating: custom_dataset/test/images/15391513324714o1n0r10n6_jpg.rf.a91fbc7be8a94ed3c48d2e4b35bd53bb.jpg
#   inflating: custom_dataset/test/images/15391513329330sooq10859_jpg.rf.89c8524c2096175fa2c728e5d73f1c28.jpg
# ...

# %% [markdown]
# ---
# ## 3. 라이브러리 버전 확인 및 커스텀데이터 train시행 (train.py / custom_dataset.yaml 이용)

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.25.2

# %%
import torch

print(torch.__version__)
# Out:
# 2.2.1+cu121

# %%
# Train YOLOv5s(maybe YOLOv5n will be accpetable in Jetson NaNo environment)
#!python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov5s.pt --cache

#!python train.py --batch 16 --epochs 20 --data "data/custom_dataset.yaml" --weights yolov5n.pt --cache

# !python train.py --batch 16 --data "data/custom_dataset.yaml" --epochs 100 --cache
# Out:
# 2024-03-24 08:38:13.115917: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 08:38:13.115968: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 08:38:13.117258: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ---
# ## 4. 커스텀

# %%
# !python val.py --data "data/custom_dataset.yaml" --weights "/content/yolov5/runs/train/exp2/weights/best.pt"
# Out:
# val: data=data/custom_dataset.yaml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/yolov5/custom_dataset/valid/labels.cache... 29 images, 0 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.01s/it]
#                    all         29        162        0.8      0.634      0.746      0.484
# ...

# %%
# !python detect.py --source 0  # webcam
                            img.jpg  # image
                            vid.mp4  # video
                            path/  # directory
                            path/*.jpg  # glob
                            'https://youtu.be/Zgi9g1ksQHc'  # YouTube
                            'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp2/weights/best.pt" --source "/content/yolov5/custom_dataset/test/images"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/yolov5/custom_dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/15 /content/yolov5/custom_dataset/test/images/0_Concern-In-China-As-Mystery-Virus-Spreads_jpg.rf.3135dfc5feab288d76a4ccfd22dfc5bf.jpg: 640x640 2 masks, 11.6ms
# ...

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp2/weights/best.pt" --source 0
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# [ WARN:0@4.154] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@4.154] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# ...
